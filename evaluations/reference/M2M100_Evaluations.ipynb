# %%
import torch
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
print("Using", device, "device")
# Out:
# Using cuda device

# %% [markdown]
# ## Load Dataset

# %%
from datasets import load_dataset
import pandas as pd

dataset = load_dataset("iwslt2017",'iwslt2017-zh-en')

# %%
from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer, pipeline

en_texts = [entry['translation']['en'] for entry in dataset['test']]
zh_texts = [entry['translation']['zh'] for entry in dataset['test']]

# %% [markdown]
# ## Model for Translation

# %%
model = M2M100ForConditionalGeneration.from_pretrained("facebook/m2m100_418M")
tokenizer = M2M100Tokenizer.from_pretrained("facebook/m2m100_418M")
m2m100_en_zh = pipeline('translation', 'facebook/m2m100_418M',device=0, src_lang='en', tgt_lang="zh")

# %% [markdown]
# ## Translate to m2m_translated.txt (For ref only)

# %%
from transformers import pipeline
from concurrent.futures import ThreadPoolExecutor, as_completed

# Initialize the translation pipeline
m2m100_en_zh = pipeline('translation', model='facebook/m2m100_418M', device=0, src_lang='en', tgt_lang='zh')

def process_batches(input_list, batch_size):
    for i in range(0, len(input_list), batch_size):
        yield input_list[i:i + batch_size]

def translate_and_write(batch):
    batch_translations = m2m100_en_zh(batch)
    
    # Write both original and translated sentences to the file
    with open("m2m_translated.txt", "a", encoding='utf-8') as fp:
        for original, translated in zip(batch, batch_translations):
            fp.write(f"{original} , \t{translated['translation_text']}\n")

# Threads
num_workers = 4  

# Translation & writing in parallel
with ThreadPoolExecutor(max_workers=num_workers) as executor:
    # Submit tasks to executor
    futures = [executor.submit(translate_and_write, batch) for batch in process_batches(en_texts, 200)]
    for future in as_completed(futures):
        future.result()

print("All translations are completed and written to the file.")
# Out:
# c:\Users\user\.conda\envs\cuda11.2\lib\site-packages\transformers\pipelines\base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# All translations are completed and written to the file.

# %% [markdown]
# ## Process txt file (For ref only)

# %%
en = []
m2m_zh = [] 
hash_map = {} 
import re

def split_eng_chinese(text):
    # Regex pattern to match English characters, digits, and common punctuation
    eng_pattern = re.compile(r'[\w\s,.\'?!;:"]+')  # Adjust the pattern as needed
    # Regex pattern to match Chinese characters (including common punctuation)
    chi_pattern = re.compile(r'[\u4e00-\u9fff，。？！；：“”（）]+')  # Add more as needed

    # Find all English and Chinese segments
    eng_segments = eng_pattern.findall(text)
    chi_segments = chi_pattern.findall(text)

    # Remove whitespace-only strings and strip leading/trailing whitespace
    eng_segments = [segment.strip() for segment in eng_segments if segment.strip() != '']
    chi_segments = [segment.strip() for segment in chi_segments if segment.strip() != '']

    return eng_segments, chi_segments

# Open the text file and read the lines
with open('m2m_translated.txt', 'r') as file:
    for line in file:
        # Strip newline characters and any trailing whitespace
        line = line.strip()
        b = line.split('\t')
        en.append(b[0][:-3])
        hash_map[b[0][:-3]] = b[1]

hash_map
# Out:
# {'And we know from that study  that when you want reality, you go to the needle.': '我們從這項研究中知道,當你想要現實時,你會去針子。',
#  "This is a seven-inch hatpin. It's very, very sharp,  and I'm going to just sterilize it a tiny bit.": '这是一个七英寸的帽子,它非常,非常尖锐,我只会精化它一点。',
#  "This is really my flesh. This is not  Damian's special-grown flesh.": '這實際上是我的肉,這不是Damian的特別生肉。',
#  "That's my skin right there. This is not a Hollywood special effect.": '这就是我的皮肤,这不是好莱坞的特殊效果。',
#  "I'm going to pierce my skin  and run this needle through to the other side.": '我要把我的皮肤擦去,把这条针推到另一边。',
#  "If you're queasy --   if you faint easily -- I was doing this for some friends  in the hotel room last night, and some people that I didn't know,  and one woman almost passed out.": '如果你是可爱的 - 如果你轻易失败 - 我昨晚在酒店房间里做了一些朋友,有些人我不知道,一个女人几乎离开了。',
#  "So, I suggest if you get queasy easy  that you look away for about the next 30 --  in fact, you know what, I'll do the first bad part behind it.": '因此,我建议,如果你得到一个轻松的,你会远离下一个30 - 事实上,你知道什么,我会做的第一个坏部分背后。',
#  "You'll get to see, you can look away too if you'd like to.": '你会看到,你也可以看,如果你想。',
#  'So, here is what happens, right here,  the beginning of my flesh  at the lower part of my arm I just make  a little pierce.': '因此,这里是发生的事情,就在这里,我的肉在我的手臂底部的开始,我只是做了一点小<unk>。',
#  "I'm sorry, man. Am I freaking you out?": '对不起,男人,我会把你赶出去吗?',
#  'OK, and then just through my skin a tiny bit,  and then out the other side like this.': '好吧,然后只是穿过我的皮肤一小点,然后出另一边,就像这样。',
#  "Now, essentially we're in the same position we were in  with the knife trick.": '现在,基本上我们处于同样的位置,我们在刀具技巧中。',
#  "But you can't count my fingers right now can you?": '但是你现在不能数我的手指,你可以吗?',
#  "So, let me show them to you. That's one, two  three, four, five.": '所以,让我向你展示它们,这就是一个,两个,三个,四个,五个。',
#  'Yes, well...': '是的,好......',
#  'I know what people think when they see this.': '我知道人们看到这一点时会想到什么。',
#  'They go, "Well, he\'s certainly not dumb enough  to stab himself through the skin to entertain us for a few minutes.': '他们走了,“好吧,他肯定不够愚蠢,以便自己穿过皮肤来娱乐我们几分钟。',
#  'So, let me give you a little peek.': '所以,讓我給你一個小小的皮克。',
#  "How's that look out there? Pretty good.": '那是什么样子呢?很好看。',
#  'Yeah, I know.   And the people in the back go, "OK, I didn\'t really see that."': '是的,我知道,背后的人们说:“好吧,我真的看不见了。',
#  'People in the satellite room are starting to move in now.': '卫星室的人们现在开始移动。',
#  'Let me give you good close look at this.': '让我们仔细看看这一点。',
#  'That really is my skin. That is not a Hollywood special effect.': '这是我的皮肤,这不是好莱坞的特殊效果。',
#  "That's my flesh, and I can twist that around.": '这就是我的肉,我可以把它转过身来。',
#  "I'm sorry. If you're getting queasy, look away,  don't look at the thing.": '我很抱歉,如果你在做什么,远离,不要看事物。',
#  'People in the back or people on video years from now watching this  will go, "Well yeah, that looks kind of neat  in some sort of effect there, but if it were real he would be --  see there\'s a hole there and a hole there, if it were real he would be bleeding.': '背部的人或观看视频的人从现在开始会说:“好,是的,看起来像在某种类型的效果,但如果它是真实的,他会 - 看到有一个洞在那里,一个洞在那里,如果它是真实的,他会出血。',
#  'Well let me work up some blood for you.': '好吧,让我为你献出一些血。',
#  'Yes, there it is.': '是的,它在那里。',
#  'Normally now, I would take the needle out.': '通常现在,我会把针子拿出来。',
#  'I would clean off my arm, and I would show you that there are no wounds.': '我要清理我的手臂,我要告诉你,没有伤口。',
#  "But I think in this context  and with the idea of taking something fake  and making it into something real,  I'm just going to leave it there,  and walk off the stage.": '但我认为,在这个背景下,并且想把一些虚假的东西变成现实的东西,我只是要把它留在那里,走出舞台。',
#  'I will be seeing you several times over the next few days.': '在接下来的几天里,我会见到你几次。',
#  "I hope you're looking forward to that. Thank you very much.": '我希望你能等到这一点,谢谢你。',
#  "So, I've known a lot of fish in my life.": '在我生命中,我认识了很多鱼。',
#  "I've loved only two.": '我只爱两个人。',
#  'That first one,  it was more like a passionate affair.': '第一個,它更像一個熱情的問題。',
#  'It was a beautiful fish:  flavorful, textured, meaty,  a bestseller on the menu.': '这是一个美丽的鱼:味道,纺织,肉,菜单上的畅销。',
#  'What a fish.': '什么鱼。',
#  'Even better,  it was farm-raised to the supposed highest standards  of sustainability.': '甚至更好地说,它被农场提升到最高的可持续性标准。',
#  'So you could feel good about selling it.': '所以,你可以感觉很好地卖掉它。',
#  'I was in a relationship with this beauty  for several months.': '我在这个美丽的关系几个月。',
#  "One day, the head of the company called  and asked if I'd speak at an event  about the farm's sustainability.": '有一天,公司负责人打电话,问我是否会在一个活动上谈论农场的可持续性。',
#  '"Absolutely," I said.': '“绝对,”我说。',
#  "Here was a company trying to solve  what's become this unimaginable problem for us chefs:  How do we keep fish on our menus?": '下面是一家公司试图解决我们厨师无法想象的问题:我们如何在菜单上保持鱼类?',
#  "For the past 50 years,  we've been fishing the seas  like we clear-cut forests.": '在过去的50年里,我们一直在钓鱼海洋,就像我们清洁砍伐森林一样。',
#  "It's hard to overstate the destruction.": '很难超越破坏。',
#  "Ninety percent of large fish, the ones we love --  the tunas, the halibuts, the salmons, swordfish --  they've collapsed.": '九十%的大鱼,我们所爱的鱼,如<unk>鱼、<unk>鱼、<unk>鱼、剑鱼,已经崩溃了。',
#  "There's almost nothing left.": '几乎没有留下任何东西。',
#  'So, for better or for worse,  aquaculture, fish farming, is going to be a part of our future.': '因此,为了更好或更糟,水产、渔业,将成为我们未来的一部分。',
#  "A lot of arguments against it:  Fish farms pollute -- most of them do anyway --  and they're inefficient. Take tuna,  a major drawback.": '很多反对的论点:鱼农会污染 - 他们中的大多数人无论如何 - 而且它们是无效的。',
#  "It's got a feed conversion ratio  of 15 to one.": '它有15到1的营养转换比例。',
#  'That means it takes fifteen pounds of wild fish  to get you one pound of farm tuna.': '这意味着需要15英镑的野生鱼,你得到一英镑的农田。',
#  'Not very sustainable.': '不太可持续。',
#  "It doesn't taste very good either.": '它也不好味道。',
#  'So here, finally,  was a company trying to do it right.': '因此,在这里,终于有一家公司试图做出正确的事情。',
#  'I wanted to support them.': '我想支持他们。',
#  'The day before the event,  I called the head of P.R. for the company.': '事件发生前一天,我为公司召唤了P.R.的负责人。',
#  "Let's call him Don.": '让我们把他称为唐。',
#  '"Don," I said, "just to get the facts straight, you guys are famous  for farming so far out to sea, you don\'t pollute."': '“不要,”我说,“只是为了让事实是正确的,你男孩是著名的种植到海边,你不污染。',
#  '"That\'s right," he said. "We\'re so far out,  the waste from our fish gets distributed,  not concentrated."': '“这是正确的,”他说,“我们走得很远,我们的鱼的废物分散,而不是集中。',
#  'And then he added,  "We\'re basically a world unto ourselves.': '然后他补充说:“我们基本上是对自己一个世界。',
#  'That feed conversion ratio? 2.5 to one," he said.': '这种营养转换比率? 2.5 到 1,“他说。',
#  '"Best in the business."': '“在商业中最好”',
#  '2.5 to one, great.': '2.5 到 1 ,很棒。',
#  '"2.5 what? What are you feeding?"': '5、你吃什么?你吃什么?',
#  '"Sustainable proteins," he said.': '“可持续的蛋白质,”他说。',
#  '"Great," I said. Got off the phone.': '“很好,”我说,“打电话了。',
#  'And that night, I was lying in bed, and I thought:  What the hell is a sustainable protein?': '那天晚上,我躺在床上,想:什么地狱是可持续的蛋白质?',
#  'So the next day, just before the event, I called Don.': '所以第二天,在事件发生前,我打电话给唐。',
#  'I said, "Don, what are some examples of sustainable proteins?"': '我说:“好吧,一些可持续的蛋白质的例子是什么?”',
#  "He said he didn't know. He would ask around.": '他说他不知道,他会问。',
#  'Well, I got on the phone with a few people in the company;  no one could give me a straight answer  until finally, I got on the phone  with the head biologist.': '好吧,我和公司的一些人打电话,没有人能给我一个直接的答案,直到最后,我和生物学家打电话。',
#  "Let's call him Don too.": '让我们把他称为唐。',
#  '"Don," I said,  "what are some examples of sustainable proteins?"': '“是的,”我说,“一些可持续的蛋白质的例子是什么?”',
#  'Well, he mentioned some algaes  and some fish meals,  and then he said chicken pellets.': '好吧,他提到一些阿尔加和一些鱼的食物,然后他说鸡尾酒。',
#  'I said, "Chicken pellets?"': '我说:“鸡尾酒吗?”',
#  'He said, "Yeah, feathers, skin,  bone meal, scraps,  dried and processed into feed."': '他說:「是的,<unk>,皮膚,骨食,<unk>,乾燥和加工到食物。',
#  'I said, "What percentage  of your feed is chicken?"': '我说:“你的食物的百分比是鸡吗?”',
#  'Thinking, you know, two percent.': '思考,你知道,百分之二。',
#  '"Well, it\'s about 30 percent," he said.': '“好吧,这是大约30%,”他说。',
#  'I said, "Don, what\'s sustainable  about feeding chicken to fish?"': '我说:“唐,吃鸡吃鱼有什么可持续的?”',
#  'There was a long pause on the line,  and he said, "There\'s just too much chicken in the world."': '路线上有一段漫长的休息时间,他说:“世界上只剩下太多鸡。',
#  'I fell out of love with this fish.': '我爱上了这条鱼。',
#  "No, not because I'm some self-righteous,  goody-two shoes foodie.": '不,不是因为我是某些自我公平的,好双鞋 foodie。',
#  'I actually am.': '我实际上是。',
#  'No, I actually fell out of love with this fish because, I swear to God,  after that conversation, the fish tasted like chicken.': '不,我真的失去了对这条鱼的爱,因为我向上帝发誓,在那场谈话之后,这条鱼吃得像鸡一样。',
#  "This second fish,  it's a different kind of love story.": '這是第二個魚,這是一種不同的愛情故事。',
#  "It's the romantic kind,  the kind where the more you get to know your fish,  you love the fish.": '这就是浪漫的品种,那种品种,你越了解你的鱼,你就越爱鱼。',
#  'I first ate it at a restaurant  in southern Spain.': '我第一次在西班牙南部的一家餐厅吃饭。',
#  'A journalist friend had been talking about this fish for a long time.': '一个朋友的记者一直在谈论这个鱼很长一段时间。',
#  'She kind of set us up.': '她把我们放在一边。',
#  'It came to the table  a bright, almost shimmering, white color.': '桌子上出现了一个明亮的,几乎闪发光的,白色的颜色。',
#  'The chef had overcooked it.': '厨师吃过了。',
#  'Like twice over.': '就像两次过了。',
#  'Amazingly, it was still delicious.': '令人惊讶的是,它仍然很美味。',
#  "Who can make a fish taste good  after it's been overcooked?": '谁能让鱼在过度煮熟后品味好?',
#  "I can't,  but this guy can.": '我不能,但这个男人可以。',
#  "Let's call him Miguel --  actually his name is Miguel.": '让我们把他叫米格尔 - 事实上他的名字是米格尔。',
#  "And no, he didn't cook the fish, and he's not a chef,  at least in the way that you and I understand it.": '而且不,他没有做饭的鱼,他不是厨师,至少在你和我理解的方式。',
#  "He's a biologist  at Veta La Palma.": '他是Veta La Palma的生物学家。',
#  "It's a fish farm in the southwestern corner of Spain.": '它是西班牙西南角的鱼农场。',
#  "It's at the tip of the Guadalquivir river.": '它位于瓜达尔基维尔河的顶部。',
#  'Until the 1980s,  the farm was in the hands of the Argentinians.': '直到20世纪80年代,农场一直在阿根廷人的手中。',
#  'They raised beef cattle  on what was essentially wetlands.': '他们在基本上是湿地上种植了牲畜。',
#  'They did it by draining the land.': '他们通过驱动土地来做到这一点。',
#  'They built this intricate series of canals,  and they pushed water off the land and out into the river.': '他们建造了这系列有趣的运河,他们把水从地上推到河里。',
#  "Well, they couldn't make it work,  not economically.": '好吧,他们不能让它工作,不是经济上。',
#  'And ecologically, it was a disaster.': '从生态角度来看,这是一个灾难。',
#  'It killed like 90 percent of the birds,  which, for this place, is a lot of birds.': '它杀死了90%的鸟类,这对这个地方来说是很多鸟类。',
#  'And so in 1982,  a Spanish company with an environmental conscience  purchased the land.': '因此,在1982年,一家有环境意识的西班牙公司收购了土地。',
#  'What did they do?': '他们做了什么?',
#  'They reversed the flow of water.': '他们转过了水的流动。',
#  'They literally flipped the switch.': '他们字面上打破了交换机。',
#  'Instead of pushing water out,  they used the channels to pull water back in.': '而不是把水推出去,他们用渠道把水推回里面。',
#  'They flooded the canals.': '他们淹没了运河。',
#  'They created a 27,000-acre fish farm --  bass, mullet,  shrimp, eel --  and in the process, Miguel and this company  completely reversed the ecological destruction.': '他们创建了一个27000英亩的鱼农场 - 巴斯,<unk>,<unk>,<unk> - 在这个过程中,米格尔和这家公司完全逆转了生态破坏。',
#  "The farm's incredible.": '农场令人难以置信。',
#  "I mean, you've never seen anything like this.": '我说,你从来没有见过这样的东西。',
#  'You stare out at a horizon  that is a million miles away,  and all you see are flooded canals  and this thick, rich marshland.': '你看到了一个距离一百万英里的地平线,你所看到的一切都是洪水的运河和这个厚而丰富的火星。',
#  'I was there not long ago with Miguel.': '很久以前,我和米格尔在一起。',
#  "He's an amazing guy,  like three parts Charles Darwin and one part Crocodile Dundee.": '他是一个令人惊叹的男孩,如三部分查尔斯·达尔文和一部分克罗科迪尔·邓迪。',
#  "Okay? There we are slogging through the wetlands,  and I'm panting and sweating, got mud up to my knees,  and Miguel's calmly conducting a biology lecture.": '好吧?在那里,我们穿过潮湿地,我在汗水和汗水,在我的膝盖上滑动,米格尔平静地进行生物学讲座。',
#  "Here, he's pointing out a rare Black-shouldered Kite.": '在这里,他指的是一个罕见的黑色<unk>的基特。',
#  "Now, he's mentioning the mineral needs of phytoplankton.": '现在,他正在提到植物植物的矿物需求。',
#  'And here, here he sees a grouping pattern  that reminds him of the Tanzanian Giraffe.': '在这里,他看到一个团体模式,让他想起坦桑尼亚吉拉夫。',
#  'It turns out, Miguel spent the better part of his career  in the Mikumi National Park in Africa.': '显然,米格尔在非洲的米库米国家公园度过了他的职业生涯的一部分。',
#  'I asked him how he became  such an expert on fish.': '我问他如何成为鱼类专家。',
#  'He said, "Fish? I didn\'t know anything about fish.': '他说:“鱼,我不知道什么。',
#  'I\'m an expert in relationships."': '“我是关系专家。',
#  "And then he's off, launching into more talk  about rare birds and algaes  and strange aquatic plants.": '然后他离开了,开始更多关于罕见的鸟类和<unk>虫和奇怪的水植物的谈话。',
#  "And don't get me wrong, that was really fascinating, you know,  the biotic community unplugged, kind of thing.": '不要误会我,这是真的令人兴奋的,你知道,生物学社区无缝,某种东西。',
#  "It's great, but I was in love.": '很棒,但我爱上了。',
#  'And my head was swooning over that  overcooked piece of delicious fish I had the night before.': '我的头在我以前的夜晚吃过的美味鱼的那个过度煮熟的碎片上。',
#  'So I interrupted him. I said,  "Miguel, what makes your fish taste so good?"': '我打断了他,我说:“米格尔,你的鱼有什么好味?”',
#  'He pointed at the algae.': '他指向了阿尔及利亚。',
#  '"I know, dude, the algae, the phytoplankton,  the relationships: It\'s amazing.': '“我知道,杜德,阿尔加,菲托普兰克顿,关系:这是令人惊叹的。',
#  'But what are your fish eating?': '你的鱼吃什么?',
#  'What\'s the feed conversion ratio?"': '什么是食物转换比率?”',
#  "Well, he goes on to tell me  it's such a rich system  that the fish are eating what they'd be eating in the wild.": '好吧,他继续告诉我这是一个如此丰富的系统,鱼正在吃他们会吃的野生动物。',
#  "The plant biomass, the phytoplankton,  the zooplankton, it's what feeds the fish.": '植物生物,植物植物植物,动物植物,就是它喂养鱼。',
#  "The system is so healthy,  it's totally self-renewing.": '系统是如此健康,它是完全自我更新。',
#  'There is no feed.': '没有食物。',
#  "Ever heard of a farm that doesn't feed its animals?": '你有没有听说过一个没有养动物的农场?',
#  'Later that day, I was driving around this property with Miguel,  and I asked him, I said, "For a place that seems so natural,  unlike like any farm I\'d ever been at,  how do you measure success?"': '那天晚些时候,我和米格尔一起开车,我问他,我说:“对于一个看起来如此自然的地方,与我曾经去过的任何农场不同,你如何衡量成功?”',
#  'At that moment, it was as if  a film director called for a set change.': '那一刻,就好像一部电影导演呼吁改变一组。',
#  'And we rounded the corner  and saw the most amazing sight:  thousands and thousands of pink flamingos,  a literal pink carpet for as far as you could see.': '然后我们转过角落,看到最令人惊叹的景色:成千上万的粉红色闪光灯,一个字面粉红色的地毯,只要你能看到。',
#  '"That\'s success," he said.': '“这是成功,”他说。',
#  '"Look at their bellies, pink.': '“看看他们的白色,粉红色。',
#  'They\'re feasting."': '他们正在庆祝”。',
#  'Feasting? I was totally confused.': '好吗?我完全混乱了。',
#  'I said, "Miguel, aren\'t they feasting on your fish?"': '我说:“米格尔,他们不是在你的鱼上吃饭吗?”',
#  '"Yes," he said.': '“是的,”他说。',
#  '"We lose 20 percent of our fish  and fish eggs to birds.': '“我们失去了20%的鱼和鱼鸡蛋给鸟类。',
#  'Well, last year, this property  had 600,000 birds on it,  more than 250 different species.': '好吧,去年,这个财产上有600,000只鸟类,超过250种不同的物种。',
#  'It\'s become, today, the largest  and one of the most important  private bird sanctuaries in all of Europe."': '今天,它已成为欧洲最大的和最重要的私人鸟类圣殿之一。',
#  'I said, "Miguel, isn\'t a thriving bird population  like the last thing you want on a fish farm?"': '我说:“米格尔,不是一个繁荣的鸟类人口像你想要的最后一件事在一个鱼农场吗?”',
#  'He shook his head, no.': '他摇头,不。',
#  'He said, "We farm extensively,  not intensively.': '他说:“我们种植广泛,而不是强烈。',
#  'This is an ecological network.': '这是一个生态网络。',
#  'The flamingos eat the shrimp.': '弗拉明多人吃了<unk>。',
#  'The shrimp eat the phytoplankton.': '胡萝卜吃了植物植物。',
#  'So the pinker the belly,  the better the system."': '因此,肚子越粉红,系统越好。',
#  "Okay, so let's review:  a farm that doesn't feed its animals,  and a farm that measures its success  on the health of its predators.": '好吧,所以让我们来看看:一个不喂养自己的动物的农场,一个在猎人的健康上衡量其成功的农场。',
#  'A fish farm, but also a bird sanctuary.': '是一家鱼农场,也是鸟类圣殿。',
#  "Oh, and by the way, those flamingos,  they shouldn't even be there in the first place.": '哦,顺便说一句,这些Flamingo,他们甚至不应该在第一位。',
#  'They brood in a town  150 miles away,  where the soil conditions  are better for building nests.': '他们在一个距离150英里的城市,在那里土壤条件是更好的建造树木。',
#  'Every morning, they fly  150 miles into the farm.': '每天早上,他们飞到农场150英里。',
#  'And every evening, they fly 150 miles back.': '每天晚上,他们飞回150英里。',
#  "They do that because they're able to follow  of highway A92.": '他们这样做,因为他们能够跟踪A92高速公路。',
#  'No kidding.': '没有Kidding。',
#  'I was imagining a "March of the Penguins" thing,  so I looked at Miguel.': '我想象着一个“企鹅之火”的东西,所以我看着米格尔。',
#  'I said, "Miguel, do they fly  150 miles to the farm,  and then do they fly  150 miles back at night?': '我说:“米格尔,他们飞到农场150英里,然后在晚上飞回150英里吗?',
#  'Do they do that for the children?"': '“他们为孩子们这样做吗?”',
#  'He looked at me like I had just quoted a Whitney Houston song.': '他看着我,好像我刚刚引用了一首威特尼休斯顿的歌曲。',
#  'He said, "No; they do it because the food\'s better."': '他说:“不,他们这样做,因为食物更好。',
#  "I didn't mention the skin of my beloved fish,  which was delicious -- and I don't like fish skin;  I don't like it seared, I don't like it crispy.": '我没有提到我所爱的鱼的皮肤,它是美味的 - 我不喜欢鱼的皮肤;我不喜欢它看,我不喜欢它生气。',
#  "It's that acrid, tar-like flavor.": '这是那种可爱的味道。',
#  'I almost never cook with it.': '我几乎从来没有用它做饭。',
#  'Yet, when I tasted it at that restaurant in southern Spain,  it tasted not at all like fish skin.': '然而,当我在西班牙南部那家餐厅尝到它时,它根本不像鱼皮。',
#  'It tasted sweet and clean,  like you were taking a bite of the ocean.': '它味道甜蜜和干净,就像你咬了一口海洋。',
#  'I mentioned that to Miguel, and he nodded.': '我向米格尔提到这一点,他沉默了。',
#  'He said, "The skin acts like a sponge.': '他说:“皮肤像蜘蛛一样行事。',
#  "It's the last defense before anything enters the body.": '这是在任何东西进入身体之前的最后防御。',
#  'It evolved to soak up impurities."': '它是为了消除污<unk>的。',
#  'And then he added,  "But our water has no impurities."': '」他說:「但我們的水沒有污<unk>。',
#  "OK. A farm that doesn't feed its fish,  a farm that measures its success  by the success of its predators.": '一个不喂养自己的鱼的农场,一个通过猎人的成功来衡量它的成功的农场。',
#  'And then I realized when he says,  "A farm that has no impurities,"  he made a big understatement,  because the water that flows through that farm  comes in from the Guadalquivir River.': '然后我意识到,当他说“没有污<unk>的农场”时,他做了一个巨大的假设,因为通过农场的水从瓜达尔基维尔河流进来。',
#  "It's a river that carries with it  all the things that rivers tend to carry these days:  chemical contaminants,  pesticide runoff.": '它是一条河流,它携带了河流往往携带的所有东西:化学污染物,农药废物。',
#  'And when it works its way through the system  and leaves,  the water is cleaner than when it entered.': '当它通过系统和叶子运行时,水比进入时更干净。',
#  'The system is so healthy, it purifies the water.': '系统是如此健康,它清洁水。',
#  "So, not just a farm that doesn't feed its animals,  not just a farm that measures its success  by the health of its predators,  but a farm that's literally a water purification plant --  and not just for those fish,  but for you and me as well.": '因此,不只是一个不喂养自己的动物的农场,不只是一个通过猎人的健康来衡量其成功的农场,而是一个字面上是水净化工厂的农场 - 不仅仅是这些鱼,而且你和我也是。',
#  'Because when that water leaves, it dumps out into the Atlantic.': '因为当水离开时,它会跳进大西洋。',
#  "A drop in the ocean, I know,  but I'll take it, and so should you,  because this love story,  however romantic,  is also instructive.": '一滴在海洋,我知道,但我会采取它,所以你应该,因为这个爱情故事,尽管浪漫,也是教导性的。',
#  "You might say it's a recipe  for the future of good food,  whether we're talking about bass or beef cattle.": '你可以说这是一个好食物的未来食谱,无论我们谈论牛肉还是牛肉。',
#  'What we need now is  a radically new conception of agriculture,  one in which the food actually tastes good.': '现在我们需要的是一个彻底新的农业概念,其中食物实际上很好。',
#  "But for a lot people,  that's a bit too radical.": '但是,对于很多人来说,这有点过于激进。',
#  "We're not realists, us foodies;  we're lovers.": '我们不是现实主义者,我们是食物;我们是爱人。',
#  "We love farmers' markets,  we love small family farms,  we talk about local food,  we eat organic.": '我们喜欢农民的市场,我们喜欢小家庭农场,我们谈论当地的食物,我们吃有机。',
#  'And when you suggest these are the things  that will ensure the future of good food,  someone, somewhere stands up and says,  "Hey guy, I love pink flamingos,  but how are you going to feed the world?"': '当你提到这些事情会确保好食物的未来时,有人在某个地方站起来说:“哦,小伙子,我喜欢粉红色的花朵,但你会怎样喂食这个世界?”',
#  'How are you going to feed the world?': '你要怎样喂食世界呢?',
#  "She wasn't going to vaccinate her kid against polio,  no way.": '她不会接种疫苗给她的孩子,没有办法。',
#  'Fine.': '美好。',
#  "Why? Because we don't have polio. And you know what?": '为什么?因为我们没有聚合物,你知道什么?',
#  "We didn't have polio in this country yesterday.": '昨天,我们在这个国家没有聚合物。',
#  "Today, I don't know, maybe a guy got on a plane in Lagos this morning,  and he's flying to LAX, right now he's over Ohio.": '今天,我不知道,也许一个男孩今天早上在拉戈斯的飞机上,他正在飞往拉克斯,现在他在俄亥俄州。',
#  "And he's going to land in a couple of hours, he's going to rent a car,  and he's going to come to Long Beach,  and he's going to attend one of these fabulous TED dinners tonight.": '他将在几个小时内登陆,他将租一辆车,他将到达长海滩,他将在今晚参加这些奇妙的TED晚餐之一。',
#  "And he doesn't know that he's infected with a paralytic disease,  and we don't either because that's the way the world works.": '他不知道他感染了一种瘫<unk>性疾病,我们也不会这样做,因为这就是世界的工作方式。',
#  "That's the planet we live on. Don't pretend it isn't.": '这就是我们生活的星球,不要假装不是。',
#  'Now, we love to wrap ourselves in lies. We love to do it.': '现在,我们喜欢把自己沉浸在谎言中,我们喜欢这样做。',
#  'Everyone take their vitamins this morning?': '今天早上每个人都会吃维生素吗?',
#  'Echinacea, a little antioxidant  to get you going.': 'Echinacea,一些抗氧化剂让你去。',
#  'I know you did because half of Americans do every day.': '我知道你这样做,因为一半的美国人每天都在做。',
#  "They take the stuff, and they take alternative medicines,  and it doesn't matter how often  we find out that they're useless.": '他们采取物品,他们采取替代药物,不管我们多么频繁发现它们是无用的。',
#  'The data says it all the time.': '数据总是这样说。',
#  'They darken your urine. They almost never do more than that.': '他们黑暗你的尿液,他们几乎从来没有做过更多。',
#  "It's okay, you want to pay 28 billion dollars for dark urine?": '好吧,你想为黑色尿液付出28亿美元吗?',
#  "I'm totally with you.": '我完全和你在一起。',
#  'Dark urine. Dark.': '黑暗,黑暗。',
#  'Why do we do that? Why do we do that?': '為什麼我們這樣做?為什麼我們這樣做?',
#  'Well, I think I understand, we hate Big Pharma.': '好吧,我认为我明白,我们讨厌大药店。',
#  "We hate Big Government. We don't trust the Man.": '我们讨厌大政府,我们不信任人。',
#  "And we shouldn't: Our health care system sucks.": '我们不应该:我们的医疗保健系统正在崩溃。',
#  "It's cruel to millions of people.": '对数以百万计的人来说是残酷的。',
#  "It's absolutely astonishingly cold  and soul-bending to those of us who can even afford it.": '它是绝对令人惊讶的寒冷和灵魂祝福的那些我们谁甚至可以放弃它。',
#  'So we run away from it, and where do we run?': '所以,我們逃離它,我們走在哪裡呢?',
#  'We leap into the arms of Big Placebo.': '我们跳进大 Placebo 的手臂。',
#  "That's fantastic. I love Big Placebo.": '这是很棒的,我喜欢大 Placebo。',
#  "But, you know, it's really a serious thing  because this stuff is crap,  and we spend billions of dollars on it.": '但是,你知道,这是真的很严重的事情,因为这个东西是麻烦的,我们花了数十亿美元。',
#  'And I have all sorts of little props here.': '我在这里有各种各样的小提议。',
#  "None of it ... ginkgo, fraud;  echinacea, fraud;  acai -- I don't even know what that is  but we're spending billions of dollars on it -- it's fraud.": '没有一个......金戈,欺诈;埃希纳西亚,欺诈;阿卡伊 - 我甚至不知道它是什么,但我们花了数十亿美元 - 这是欺诈。',
#  'And you know what? When I say this stuff, people scream at me,  and they say, "What do you care? Let people do what they want to do.': '当我说这些话时,人们向我大喊大叫,他们说:“你关心什么?让人们做他们想做的事情。',
#  'It makes them feel good."': '这让他们感觉好”。',
#  "And you know what? You're wrong.": '你知道什么?你错了。',
#  'Because I don\'t care  if it\'s the secretary of HHS  who\'s saying, "Hmm, I\'m not going to take the evidence  of my experts on mammograms,"  or some cancer quack who wants to treat his patient  with coffee enemas.': '因为我不在乎是否是HHS的秘书谁说,“Hmm,我不会采取我的专家的证据关于乳房”或一些癌症的麻烦谁想要治疗他的病人与咖啡麻烦。',
#  "When you start down the road  where belief and magic replace evidence and science,  you end up in a place you don't want to be.": '當你開始信仰和魔術取代證據和科學的道路時,你結束在一個你不想成為的地方。',
#  'You end up in Thabo Mbeki South Africa. He killed 400,000 of his people  by insisting that beetroot,  garlic and lemon oil  were much more effective than the antiretroviral drugs  we know can slow the course of AIDS.': '他杀死了他的40万人,坚持大豆、胡萝卜和<unk>檬油比我们所知道的抗病毒药物更有效,可以缓慢艾滋病的进程。',
#  'Hundreds of thousands of needless deaths  in a country that has been plagued  worse than any other by this disease.': '数以百万计的不必要死亡在一个已受伤的国家比任何其他疾病更糟糕。',
#  "Please, don't tell me  there are no consequences to these things.": '请不要告诉我这些事情没有任何后果。',
#  'There are. There always are.': '有,有,总是有。',
#  "Now, the most mindless epidemic  we're in the middle of right now  is this absurd battle  between proponents of genetically engineered food  and the organic elite.": '现在,我们正处于中间最无意识的流行病是基因化食品的支持者和有机精英之间的这种荒谬的斗争。',
#  "It's an idiotic debate. It has to stop.": '这是一个愚蠢的辩论,必须停止。',
#  "It's a debate about words, about metaphors.": '这是关于词语的讨论,关于形象的讨论。',
#  "It's ideology, it's not science.": '这是意识形态,不是科学。',
#  'Every single thing we eat, every grain of rice,  every sprig of parsley,  every Brussels sprout  has been modified by man.': '我们吃的每件事,每种大米,每种草莓,每种布鲁塞尔草莓都被人类改变了。',
#  "You know, there weren't tangerines in the garden of Eden.": '你知道,在埃登的花园里没有<unk>虫。',
#  "There wasn't any cantaloupe.   There weren't Christmas trees. We made it all.": '没有圣诞树,没有圣诞树,我们做了一切。',
#  'We made it over the last 11,000 years.': '我们在过去的11000年里做了这一点。',
#  "And some of it worked, and some of it didn't.": '其中的一部分工作了,其中的一部分没有。',
#  "We got rid of the stuff that didn't.": '我们摆脱了没有做的事情。',
#  'Now we can do it in a more precise way --  and there are risks, absolutely --  but we can put something like vitamin A into rice,  and that stuff can help millions of people,  millions of people, prolong their lives.': '现在我们可以以更准确的方式做到这一点 - 而且有风险,绝对 - 但我们可以把维生素A等东西放在大米里,这些东西可以帮助数百万人,数百万人,延长他们的生命。',
#  "You don't want to do that?": '你不想这样做吗?',
#  "I have to say, I don't understand it.": '我要说,我不明白。',
#  'We object to genetically engineered food.': '我们反对基因制造的食物。',
#  'Why do we do that?': '为什么我们这样做?',
#  "Well, the things I constantly hear are:  Too many chemicals,  pesticides, hormones,  monoculture, we don't want giant fields  of the same thing, that's wrong.": '好吧,我常常听到的就是:太多的化学物质,农药,荷尔蒙,单文化,我们不想要同样的巨大的领域,这是错误的。',
#  "We don't companies patenting life.": '我们不是公司专利生命。',
#  "We don't want companies owning seeds.": '我们不希望公司拥有种子。',
#  'And you know what my response to all of that is?': '你知道我对这一切的回应是什么吗?',
#  "Yes, you're right. Let's fix it.": '是的,你说得对,让我们修好吧。',
#  "It's true, we've got a huge food problem,  but this isn't science.": '事实上,我们有一个巨大的食物问题,但这不是科学。',
#  'This has nothing to do with science.': '这与科学无关。',
#  "It's law, it's morality, it's patent stuff.": '这是法律,这是道德,这是专利。',
#  "You know science isn't a company.": '你知道,科学不是公司。',
#  "It's not a country.": '这不是一个国家。',
#  "It's not even an idea; it's a process.": '它甚至不是一个想法;它是一个过程。',
#  "It's a process, and sometimes it works and sometimes it doesn't,  but the idea that we should not allow  science to do its job  because we're afraid,  is really very deadening,  and it's preventing millions of people  from prospering.": '这是一个过程,有时它工作,有时它不行,但我们不应该让科学做自己的工作,因为我们害怕,这个想法是非常令人震惊的,它阻止了数百万人繁荣。',
#  "You know, in the next 50 years  we're going to have to grow 70 percent more food than we do right now,  70 percent.": '你知道,在接下来的50年里,我们将不得不增加70%的食物比我们现在做的,70%。',
#  'This investment in Africa over the last 30 years.': '在过去的30年里,这项投资在非洲。',
#  'Disgraceful. Disgraceful.': '可耻,可耻。',
#  "They need it, and we're not giving it to them.": '他们需要它,我们不给他们。',
#  'And why? Genetically engineered food.': '為什麼?基因設計的食物',
#  "We don't want to encourage people  to eat that rotten stuff, like cassava for instance.": '我们不想鼓励人们吃这些腐烂的东西,例如卡萨瓦。',
#  "Cassava's something that half a billion people eat.": '卡萨瓦是半亿人吃的东西。',
#  "It's kind of like a potato.": '它就像一块土豆。',
#  "It's just a bunch of calories. It sucks.": '它只是一堆卡路里,它会消化。',
#  "It doesn't have nutrients, it doesn't have protein,  and scientists are engineering  all of that into it right now.": '它没有营养素,它没有蛋白质,科学家现在正在工程这一切。',
#  "And then people would be able to eat it and they'd be able to not go blind.": '然后,人们可以吃它,他们不能失明。',
#  "They wouldn't starve, and you know what?": '他们不会饿了,你知道什么?',
#  "That would be nice. It wouldn't be Chez Panisse,  but it would be nice.": '它不会是Chez Panisse,但它会很好。',
#  'And all I can say about this is:  Why are we fighting it?': '我可以说的是:我们为什么要战斗呢?',
#  "I mean, let's ask ourselves: Why are we fighting it?": '我想,让我们问自己:为什么我们正在战斗它?',
#  "Because we don't want to move genes around?": '因为我们不想移动基因。',
#  "This is about moving genes around. It's not about chemicals.": '這是關於移動基因,不是關於化學物質。',
#  "It's not about our ridiculous passion for hormones,  our insistence on having bigger food,  better food, singular food.": '这不是关于我们对荷尔蒙的荒谬热情,我们坚持拥有更大的食物,更好的食物,独特的食物。',
#  "This isn't about Rice Krispies,  this is about keeping people alive,  and it's about time we started to understand what that meant.": '这不是关于Rice Krispies,这是关于让人们活着,现在是时候我们开始了解这意味着什么。',
#  'Because, you know something?': '因为,你知道什么吗?',
#  "If we don't, if we continue to act the way we're acting,  we're guilty of something that I don't think we want to be guilty of:  high-tech colonialism.": '如果我们不这样做,如果我们继续按照我们行动的方式行事,我们对我认为我们不想犯的某件事有罪:高科技殖民主义。',
#  "There's no other way to describe what's going on here.": '没有别的办法来描述这里正在发生的事情。',
#  "It's selfish, it's ugly,  it's beneath us,  and we really have to stop it.": '它是自私的,它是丑陋的,它在我们下面,我们真的必须停止它。',
#  'So after this amazingly fun conversation,    you might want to say, "So, you still want to get in this  ridiculous time machine and go forward?"': '所以,在这个令人难以置信的有趣的谈话之后,你可能想说:“所以,你仍然想进入这个荒谬的时间机器,然后继续前进吗?”',
#  'Absolutely. Absolutely, I do.': '绝对!绝对,我做。',
#  "It's stuck in the present right now,  but we have an amazing opportunity.": '它已经陷入了现在,但我们有一个令人难以置信的机会。',
#  'We can set that time machine on anything we want.': '我们可以把这个时间机器放在我们想要的任何东西上。',
#  "We can move it where we want to move it,  and we're going to move it where we want to move it.": '我们可以把它移动到我们想要移动的地方,我们将把它移动到我们想要移动的地方。',
#  "We have to have these conversations and we have to think,  but when we get in the time machine and we go ahead,  we're going to be happy we do.": '我们必须有这些谈话,我们必须思考,但当我们进入时间机器,我们继续前进时,我们会很高兴。',
#  "I know that we can,  and as far as I'm concerned,  that's something the world needs right now.": '我知道我们可以,在我所关心的范围内,这就是世界现在需要的东西。',
#  'Thank you.': '谢谢你',
#  'One day, Los Angeles Times columnist  Steve Lopez was walking along  the streets of downtown Los Angeles  when he heard beautiful music.': '有一天,洛杉矶时报的作家史蒂夫·洛佩斯在洛杉矶市中心的街道上散步,听到美丽的音乐。',
#  'And the source was a man,  an African-American man,  charming, rugged, homeless,  playing a violin that only had two strings.': '起源是一个男人,一个非洲裔美国人,迷人的,粗糙的,无家可归的,玩着一个只有两条线的紫色。',
#  "And I'm telling a story that many of you know,  because Steve's columns became the basis  for a book, which was turned into a movie,  with Robert Downey Jr. acting as Steve Lopez,  and Jamie Foxx as Nathaniel Anthony Ayers,  the Juilliard-trained double bassist  whose promising career was cut short  by a tragic affliction with paranoid schizophrenia.": '我正在讲述一个故事,你们中的许多人知道,因为史蒂夫的柱子成为了一本书的基础,它变成了一部电影,罗伯特·道尼·朱尼(Robert Downey Jr.)扮演史蒂夫·洛佩斯(Steve Lopez)和詹米·福克斯(Jamie Foxx)扮演纳塔尼尔·安东尼·艾尔斯(Nathaniel Anthony Ayers),朱利亚德训练的双重 bassist,他的有前途的职业生涯被一场悲剧性的悲伤中缩短。',
#  'Nathaniel dropped out of Juilliard, he suffered a complete breakdown,  and 30 years later he was living homeless  on the streets of Skid Row in downtown Los Angeles.': '纳塔尼尔离开了朱利亚德,他遭受了一场彻底的崩溃,30年后,他在洛杉矶市中心的斯基德罗的街道上无家可归。',
#  "I encourage all of you to read Steve's book or to watch the movie  to understand not only the beautiful bond  that formed between these two men,  but how music helped shape that bond,  and ultimately was instrumental -- if you'll pardon the pun --  in helping Nathaniel get off the streets.": '我鼓励你们所有人阅读史蒂夫的书或观看这部电影,以了解这两个人之间形成的美丽联系,但音乐如何帮助形成这种联系,最终是乐器的 - 如果你会原谅惩罚 - 帮助纳塔尼尔走出街道。',
#  'I met Mr. Ayers in 2008,  two years ago, at Walt Disney Concert Hall.': '我在2008年,两年前,在沃尔特迪士尼音乐厅见过艾尔斯先生。',
#  "He had just heard a performance of Beethoven's First and Fourth symphonies,  and came backstage and introduced himself.": '他刚刚听到贝多芬的第一和第四交响曲的表演,然后回到后台,介绍了自己。',
#  "He was speaking in a very jovial and gregarious way  about Yo-Yo Ma and Hillary Clinton  and how the Dodgers were never going to make the World Series,  all because of the treacherous first violin passage work in the last movement of Beethoven's Fourth Symphony.": '他对Yo-Yo Ma和希拉里·克林顿(Hillary Clinton)和多德格斯(Dodgers)从来没有做过世界系列,所有这些都是因为贝多芬第四交响曲的最后一场动作中背叛的第一段小说。',
#  'And we got talking about music, and I got an email from Steve a few days later  saying that Nathaniel was interested in a violin lesson with me.': '我们谈到了音乐,几天后,我收到史蒂夫的一封电子邮件,说纳塔尼尔对我有兴趣的歌曲教训。',
#  'Now, I should mention that Nathaniel refuses treatment  because when he was treated it was with shock therapy  and Thorazine and handcuffs,  and that scar has stayed with him for his entire life.': '现在,我应该提到,纳塔尼尔拒绝治疗,因为当他接受治疗时,他接受了冲击治疗和Thorazine和手套,而这只<unk>子一生都留在他身边。',
#  'But as a result now, he is prone to  these schizophrenic episodes,  the worst of which can manifest themselves as  him exploding  and then disappearing for days,  wandering the streets of Skid Row,  exposed to its horrors, with the torment of his own mind  unleashed upon him.': '但是,现在,他对这些精神分裂的事件感到敏感,其中最糟糕的是,他爆炸,然后几天消失,走在斯基德罗的街道上,暴露于他的恐惧,他的心灵的折磨在他身上。',
#  'And Nathaniel was in such a state of agitation  when we started our first lesson at Walt Disney Concert Hall --  he had a kind of manic glint in his eyes,  he was lost.': '当我们在沃尔特迪士尼音乐厅开始我们的第一课时,纳塔尼尔处于这种紧张状态 - 他眼中有一种迷人的眼光,他失去了。',
#  'And he was talking about  invisible demons and smoke,  and how someone was poisoning him in his sleep.': '他谈到了看不见的恶魔和烟雾,以及有人在睡眠中如何毒害他。',
#  'And I was afraid,  not for myself, but I was afraid  that I was going to lose him,  that he was going to sink into one of his states,  and that I would ruin his relationship with the violin  if I started talking about scales  and arpeggios and other exciting forms of  didactic violin pedagogy.': '我害怕,不是为了我自己,但我害怕我会失去他,他会沉浸在他的一个国家,如果我开始谈论岩石和<unk>子和其他令人兴奋的形式的教学<unk>子教学,我会破坏他的关系。',
#  'So, I just started playing.': '所以,我刚刚开始玩。',
#  'And I played the first movement of the Beethoven Violin Concerto.': '我演奏了Beethoven Violin音乐会的第一场动作。',
#  "And as I played,  I understood that there was a profound change  occurring in Nathaniel's eyes.": '在我玩的时候,我意识到纳塔尼尔的眼睛里发生了深刻的变化。',
#  'It was as if he was in the grip of some invisible pharmaceutical,  a chemical reaction, for which my playing the music  was its catalyst.': '就好像他在某种看不见的药物,一个化学反应,我的演奏音乐是它的催化剂。',
#  "And Nathaniel's manic rage  was transformed into understanding,  a quiet curiosity and grace.": '纳塔尼尔的迷人的愤怒变成了理解,一个安静的好奇心和恩典。',
#  "And in a miracle, he lifted his own violin  and he started playing, by ear,  certain snippets of violin concertos  which he then asked me to complete -- Mendelssohn,  And we started talking about music, from Bach  to Beethoven and Brahms,  Bruckner, all the B's,  from Bartók, all the way up to Esa-Pekka Salonen.": '在一个奇迹中,他举起自己的钢琴,他开始听到一些钢琴音乐会的剪辑,然后他要求我完成 - Mendelssohn,我们开始谈论音乐,从巴赫到贝多芬和布鲁克纳,所有的B,从巴托克,整个道路到Esa-Pekka Salonen。',
#  'And I understood that he not only  had an encyclopedic knowledge of music,  but he related to this music at a personal level.': '我明白,他不仅有音乐的百科全书知识,而且在个人层面上与音乐有关。',
#  'He spoke about it with the kind of passion  and understanding that I share with my colleagues  in the Los Angeles Philharmonic.': '他用我与洛杉矶哲学院的同事分享的热情和理解来谈论这一点。',
#  'And through playing music and talking about music,  this man had transformed  from the paranoid, disturbed man  that had just come from walking the streets  of downtown Los Angeles  to the charming, erudite,  brilliant, Juilliard-trained musician.': '通过演奏音乐和谈论音乐,这个男人从偏执的,烦恼的男人,刚刚从走在洛杉矶市中心的街道到迷人的,聪明的,辉煌的,朱利亚德训练的音乐家转变。',
#  'Music is medicine. Music changes us.': '音乐是医学,音乐改变了我们。',
#  'And for Nathaniel, music is sanity.': '对于纳塔尼尔来说,音乐就是健康。',
#  'Because music allows him to take his thoughts  and delusions and shape them  through his imagination and his creativity,  into reality.': '因为音乐使他能够通过自己的想象力和创造力将自己的想法和幻想转化为现实。',
#  'And that is an escape  from his tormented state.': '這是一個逃避他受折磨的國家。',
#  'And I understood that this was the very essence of art.': '我明白,这就是艺术的本质。',
#  "This was the very reason why we made music,  that we take something that exists within all of us  at our very fundamental core,  our emotions,  and through our artistic lens,  through our creativity, we're able to shape those emotions into reality.": '这就是为什么我们创造了音乐,我们把我们所有人的内心存在的东西带到我们非常基本的核心,我们的情绪,通过我们的艺术镜头,通过我们的创造力,我们能够把这些情绪变成现实。',
#  'And the reality of that expression  reaches all of us  and moves us, inspires and unites us.': '这个表达的现实,到达我们所有人,引导我们,激励我们,团结我们。',
#  'And for Nathaniel,  music brought him back into a fold of friends.': '对于纳塔尼尔来说,音乐把他带回了朋友群中。',
#  'The redemptive power of music brought him back  into a family of musicians  that understood him,  that recognized his talents  and respected him.': '音乐的救赎力量把他带回一个音乐家家庭,他们理解他,他们认识到他的天赋,并尊重他。',
#  "And I will always make music with Nathaniel,  whether we're at Walt Disney Concert Hall  or on Skid Row, because he reminds me  why I became a musician.": '我总是会和纳塔尼尔一起唱音乐,无论我们在沃尔特迪士尼音乐厅还是在斯基德罗,因为他提醒我为什么我成为音乐家。',
#  'Bruno Giussani: Thank you. Thanks.': '布鲁诺·朱桑尼:谢谢!谢谢!',
#  'Robert Gupta.': '罗伯特·古普塔',
#  "Robert Gupta: I'm going to play something that I shamelessly stole from cellists.": '罗伯特·古普塔(Robert Gupta):我将扮演一些我无耻地从细胞主义者身上偷走的东西。',
#  'So, please forgive me.': '所以,请原谅我。',
#  "I'm Jane McGonigal. I'm a game designer.": '我是Jane McGonigal,我是游戏设计师。',
#  "I've been making games online now for 10 years,  and my goal for the next decade  is to try to make it as easy to save the world in real life  as it is to save the world in online games.": '我已经在网上玩游戏已经10年了,我的目标是为下一个十年尝试使世界在现实生活中如此轻松,以便在网上玩游戏中拯救世界。',
#  'Now, I have a plan for this,  and it entails convincing more people,  including all of you, to spend more time playing bigger and better games.': '现在,我有一个计划,这意味着说服更多的人,包括你们所有人,花更多的时间玩更大和更好的游戏。',
#  'Right now we spend three billion hours a week playing online games.': '目前,我们每周花费30亿小时在网上玩游戏。',
#  'Some of you might be thinking,  "That\'s a lot of time to spend playing games.': '你們中的一些人可能會想,「玩遊戲花了很多時間。',
#  'Maybe too much time,  considering how many urgent problems we have to solve in the real world."': '也许太多的时间,考虑到我们在现实世界中需要解决多少紧急问题。',
#  'But actually, according to my research at the Institute for the Future,  actually the opposite is true.': '但事实上,根据我对未来研究所的研究,实际上相反是真实的。',
#  "Three billion hours a week is not nearly enough game play  to solve the world's most urgent problems.": '每周三十亿小时几乎没有足够的游戏来解决世界上最紧急的问题。',
#  'In fact, I believe that if we want to survive  the next century on this planet,  we need to increase that total dramatically.': '事实上,我相信,如果我们想在这个星球上生存下一个世纪,我们需要大幅增加这一总数。',
#  "I've calculated the total we need  at 21 billion hours of game play every week.": '我已经计算了我们每周需要的总数为21亿小时的游戏。',
#  "So, that's probably a bit of a counter-intuitive idea,  so I'll say it again, let it sink in:  If we want to solve problems like hunger,  poverty, climate change, global conflict, obesity,  I believe that we need to aspire to play games online  for at least 21 billion hours a week, by the end of the next decade.": '因此,这可能是一个反直觉的想法,所以我会再说一遍,让它沉浸在:如果我们想解决饥饿,贫困,气候变化,全球冲突,肥胖等问题,我认为我们需要追求在网上玩游戏至少21亿小时每周,到下一个十年结束。',
#  "No. I'm serious. I am.": '是的,我很认真,是的。',
#  "Here's why.": '这就是为什么。',
#  'This picture pretty much sums up why I think games are so essential  to the future survival of the human species.  Truly.': '这个图像几乎总结了为什么我认为游戏对人类未来的生存至关重要。',
#  'This is a portrait by photographer Phil Toledano.': '这是摄影师菲尔·托莱达诺的肖像。',
#  'He wanted to capture the emotion of gaming,  so he set up a camera in front of gamers while they were playing.': '他想捕捉游戏的情感,所以他在玩游戏时在玩家面前安装了相机。',
#  'And this is a classic gaming emotion.': '这是一个经典的游戏情绪。',
#  "Now, if you're not a gamer,  you might miss some of the nuance in this photo.": '现在,如果你不是玩家,你可能错过了这张照片的一些色调。',
#  'You probably see the sense of urgency,  a little bit of fear, but intense concentration,  deep, deep focus on tackling a really difficult problem.': '你可能看到紧急的感觉,有点恐惧,但强烈的集中力,深深的焦点,解决一个真正困难的问题。',
#  'If you are a gamer, you will notice a few nuances here:  the crinkle of the eyes up, and around the mouth  is a sign of optimism,  and the eyebrows up is surprise.': '如果你是一名玩家,你会注意到一些色调在这里:眼睛的尖叫,周围的嘴是乐观的迹象,眼睛的尖叫是惊喜。',
#  'This is a gamer who\'s on the verge of something called an "epic win."': '这是一个玩家在所谓的“流行胜利”的边缘。',
#  "Oh, you've heard of that.": '哦,你听说过这一点。',
#  'OK, good, so we have some gamers among us.': '好吧,好吧,所以我们中间有几个玩家。',
#  'An epic win is an outcome that is so extraordinarily positive,  you had no idea it was even possible until you achieved it.': '一个传奇的胜利是一个非常积极的结果,你没有意识到它甚至是可能的,直到你实现了它。',
#  "It was almost beyond the threshold of imagination, and when you get there,  you're shocked to discover what you're truly capable of.": '它几乎超越了想象的边界,当你到达那里时,你很震惊地发现你真正能做什么。',
#  "That's an epic win.": '这是一个传奇的胜利。',
#  'This is a gamer on the verge of an epic win.': '这是一个玩家在一个传奇的胜利的边缘。',
#  'And this is the face that we need to see  on millions of problem-solvers all over the world  as we try to tackle the obstacles of the next century --  the face of someone who, against all odds,  is on the verge of an epic win.': '这就是我们需要看到的面孔,在世界各地的数百万问题解决者,当我们试图解决下一个世纪的障碍时 - 面对某人,反对所有的可能性,处于一个传奇的胜利的边缘。',
#  'Now, unfortunately this is more of the face that we see in everyday life now as we try to tackle urgent problems.': '现在,不幸的是,这是我们在日常生活中看到的更多面孔,当我们试图解决紧急问题时。',
#  'This is what I call the "I\'m Not Good At Life" face.': '这就是我称之为“我在生活中不好”的面孔。',
#  'This is actually me making it. Can you see? Yes. Good.': '这就是我真正的做法吗?你能看见吗?是的。',
#  'This is me making the "I\'m Not Good At Life" face.': '这就是我在做“我不是好生活”的面孔。',
#  "This is a piece of graffiti in my old neighborhood in Berkeley, California, where I did my PhD  on why we're better in games than we are in real life.": '这是我在加利福尼亚伯克利(Berkeley)的老邻居的一块格拉菲蒂,我在那里做了我的博士学位,为什么我们在游戏中比我们在现实生活中更好。',
#  'And this is a problem that a lot of gamers have.': '这是很多玩家所面临的问题。',
#  'We feel that we are not as good in reality as we are in games.': '我们觉得我们在现实中并不像我们在游戏中那样好。',
#  "I don't mean just good as in successful, although that's part of it.": '我不只是在成功中意味着好,尽管这也是其中的一部分。',
#  'We do achieve more in game worlds.': '我们在游戏世界中取得了更多的成就。',
#  'But I also mean good as in motivated to do something that matters --  inspired to collaborate and to cooperate.': '但我也指的是善,如同有动机做一些有意义的事情――激励合作和合作。',
#  "And when we're in game worlds,  I believe that many of us become the best version of ourselves --  the most likely to help at a moment's notice,  the most likely to stick with a problem as long at it takes,  to get up after failure and try again.": '当我们在游戏世界中时,我相信我们中的许多人会成为我们最好的版本 - 最有可能在某个时刻注意到帮助,最有可能在需要的时间内坚持一个问题,在失败后站起来,再次尝试。',
#  "And in real life, when we face failure,  when we confront obstacles, we often don't feel that way.": '在现实生活中,当我们面对失败时,当我们面对障碍时,我们往往不会这样感觉。',
#  'We feel overcome, we feel overwhelmed,  we feel anxious, maybe depressed, frustrated or cynical.': '我们感到过度,我们感到过度,我们感到焦虑,也许抑郁,失望或愤世嫉俗。',
#  "We never have those feelings when we're playing games,  they just don't exist in games.": '我们在玩游戏时从来没有这些感觉,它们只是在游戏中不存在。',
#  "So that's what I wanted to study when I was a graduate student.": '所以这就是我想学习的,当我是毕业生时。',
#  "What about games makes it impossible  to feel that we can't achieve everything?": '什么是游戏使我们无法感觉到我们无法实现一切?',
#  'How can we take those feelings from games  and apply them to real-world work?': '我们如何从游戏中取出这些感受,并将其应用于现实世界工作?',
#  'So I looked at games like World of Warcraft,  which is really the ideal collaborative problem-solving environment.': '所以我看到了像World of Warcraft这样的游戏,这实际上是理想的合作解决问题环境。',
#  'And I started to notice a few things  that make epic wins so possible in online worlds.': '而且,我开始注意到一些事情使传奇胜利在网上世界尽可能。',
#  'The first thing is whenever you show up in one of these online games,  especially in World of Warcraft,  there are lots and lots of different characters  who are willing to trust you with a world-saving mission, right away.': '第一件事是,每当你出现在其中一个在线游戏,特别是在World of Warcraft,有很多和很多不同的角色,谁愿意信任你一个世界拯救的任务,立即。',
#  "But not just any mission,  it's a mission that is perfectly matched with your current level in the game.": '但不只是任何任务,这是一个任务,完全符合你的当前水平在游戏中。',
#  'Right? So you can do it.': '是吗?你可以这样做。',
#  "They never give you a challenge you can't achieve.": '他们永远不会给你一个你无法实现的挑战。',
#  "But it is on the verge of what you're capable of, so you have to try hard.": '但它是你能做的事情的边缘,所以你必须努力。',
#  "But there's no unemployment in World of Warcraft; no sitting around,  wringing your hands --  there's always something specific and important to be done.": '但在Warcraft世界中没有失业;没有坐在周围,伸出你的手 - 总是有一些具体和重要的事情要做。',
#  'There are also tons of collaborators.': '还有数以百计的合作伙伴。',
#  'Everywhere you go, hundreds of thousands of people  ready to work with you to achieve your epic mission.': '无论你去哪里,成千上万的人都准备好与你合作,以实现你的传奇任务。',
#  "That's not something we have in real life that easily,  this sense that at our fingertips are tons of collaborators.": '这不是我们在现实生活中所拥有的东西,这很容易,这意味着我们的指纹上有成千上万的合作伙伴。',
#  "And there's this epic story, this inspiring story of why we're there,  and what we're doing,  and we get all this positive feedback.": '还有这个传奇的故事,这个启发性的故事,为什么我们在那里,我们正在做什么,我们得到这一切积极的反馈。',
#  'You guys have heard of leveling up, +1 strength, +1 intelligence.': '你們男孩已經聽到平衡, +1 力量, +1 智慧。',
#  "We don't get that kind of constant feedback in real life.": '我们不会在现实生活中获得这种不断的反馈。',
#  "When I get off this stage,  I'm not going to have +1 speaking, and +1 crazy idea,  +20 crazy idea.": '当我离开这个阶段时,我不会有 +1 说话, + 1 疯狂的想法, + 20 疯狂的想法。',
#  "I don't get that feedback in real life.": '我不会在现实生活中得到这样的反馈。',
#  "Now, the problem with collaborative online environments like World of Warcraft  is that it's so satisfying to be on the verge of an epic win all the time,  we decide to spend all our time in these game worlds.": '现在,与合作的在线环境如World of Warcraft的问题是,它是如此令人满意的,在一个传奇的胜利的边缘整个时间,我们决定花所有的时间在这些游戏世界。',
#  "It's just better than reality.": '只是比现实更好。',
#  'So, so far, collectively all the World of Warcraft gamers  have spent 5.93 million years  solving the virtual problems of Azeroth.': '因此,到目前为止,全世界的Warcraft玩家已经花了593万年的时间来解决阿塞罗特的虚拟问题。',
#  "Now, that's not necessarily a bad thing.": '现在,这不一定是坏事。',
#  'Several years ago here at TED, Peter Skillman  introduced a design challenge  called the marshmallow challenge.': '几年前,在这里在TED,彼得·斯基尔曼介绍了一个设计挑战称为马斯马洛挑战。',
#  "And the idea's pretty simple:  Teams of four have to build the tallest free-standing structure  out of 20 sticks of spaghetti,  one yard of tape, one yard of string  and a marshmallow.": '这个想法很简单:四个团队必须从20块蜘蛛、一块绳子、一块绳子和一块火柴中建造最高的自由站式结构。',
#  'The marshmallow has to be on top.': '马歇尔必须在顶部。',
#  "And, though it seems really simple, it's actually pretty hard  because it forces people  to collaborate very quickly.": '虽然它看起来很简单,但它实际上是相当困难的,因为它迫使人们非常快地合作。',
#  'And so, I thought this was an interesting idea,  and I incorporated it into a design workshop.': '因此,我认为这是一个有趣的想法,我把它纳入了一个设计研讨会。',
#  'And it was a huge success.': '这是一个巨大的成功。',
#  "And since then, I've conducted  about 70 design workshops across the world  with students and designers and architects,  even the CTOs of the Fortune 50,  and there's something about this exercise  that reveals very deep lessons  about the nature of collaboration,  and I'd like to share some of them with you.": '从那时起,我与学生和设计师和建筑师,甚至Fortune 50的CTO,在世界各地举办了大约70个设计研讨会,这项练习揭示了关于合作的深度教训,我希望与您分享一些。',
#  'So, normally, most people begin  by orienting themselves to the task.': '因此,通常,大多数人开始将自己转向任务。',
#  "They talk about it, they figure out what it's going to look like,  they jockey for power.": '他们谈论它,他们知道它会是什么样子,他们为权力玩耍。',
#  'Then they spend some time planning, organizing,  they sketch and they lay out spaghetti.': '然后,他们花了一些时间来规划,组织,他们绘制,并放出垃圾桶。',
#  'They spend the majority of their time  assembling the sticks into ever-growing structures.': '他们花了大部分时间把<unk>子聚集在不断增长的结构中。',
#  "And then finally, just as they're running out of time,  someone takes out the marshmallow,  and then they gingerly put it on top,  and then they stand back, and -- ta-da! --  they admire their work.": '最后,正如他们走出时间一样,有人拿出火柴,然后他们轻轻地把它放在上面,然后他们站了起来,他们 - 达! - 欣赏他们的工作。',
#  'But what really happens, most of the time,  is that the "ta-da" turns into an "uh-oh,"  because the weight of the marshmallow causes the entire structure  to buckle and to collapse.': '但真正发生的事情,大多数时候,是“ta-da”变成一个“uh-oh”,因为火柴的重量会导致整个结构崩溃和崩溃。',
#  'So there are a number of people  who have a lot more "uh-oh" moments than others,  and among the worst are recent graduates of business school.': '因此,有很多人比其他人有更多的“uh-oh”时刻,最糟糕的是最近的商学院毕业生。',
#  'They lie, they cheat, they get distracted  and they produce really lame structures.': '他们在说谎,他们在欺骗,他们被分散,他们产生真正的<unk>结构。',
# ...
#  'And I talked them into funding an expedition.': '我向他们讲话,以便资助一场探险。',
#  'Sounds crazy. But this goes back to that theme  about your imagination creating a reality.': '听起来很疯狂,但这回归于你的想象力创造现实的主题。',
#  'Because we actually created a reality where six months later,  I find myself in a Russian submersible  two and a half miles down in the north Atlantic,  looking at the real Titanic through a view port.': '因為我們實際上創造了一個現實,六個月後,我發現自己在一個俄羅斯潜水的兩英里在大西洋北部,看看真正的泰坦尼克斯通過一個景色港口。',
#  'Not a movie, not HD -- for real.': '不是电影,不是HD,是真实的。',
#  'Now, that blew my mind.': '现在,这让我心碎了。',
#  'And it took a lot of preparation, we had to build cameras  and lights and all kinds of things.': '而且需要很多准备,我们不得不建造相机和灯光,以及各种各样的东西。',
#  'But, it struck me how much  this dive, these deep dives,  was like a space mission.': '但是,我感到震惊的是,这个潜水,这些深深的潜水,就像一个太空任务一样。',
#  'You know, where it was highly technical,  and it required enormous planning.': '你知道,它是非常技术的,需要巨大的规划。',
#  "You get in this capsule, you go down to this dark  hostile environment  if you can't get back by yourself.": '你进入这个胶囊,你下到这个黑暗的敌对环境,如果你不能自己回来。',
#  'And I thought like, "Wow. I\'m like,  living in a science fiction movie.': '我想:“Wow,我喜欢,生活在一个科幻电影。',
#  'This is really cool."': '这真的很酷”。',
#  'And so, I really got bitten by the bug of deep-ocean exploration.': '因此,我真的被深海探索的错误所困扰。',
#  'Of course, the curiosity, the science component of it --  it was everything. It was adventure,  it was curiosity, it was imagination.': '当然,好奇心,它的科学组成部分,就是一切,就是冒险,就是好奇心,就是想象力。',
#  "Hollywood couldn't give me.": '好莱坞不能给我。',
#  "Because, you know, I could imagine a creature and we could  create a visual effect for it. But I couldn't imagine what I was seeing  out that window.": '因为,你知道,我可以想象一个生物,我们可以为它创造一个视觉效果,但我无法想象我在那个窗外看到什么。',
#  'As we did some of our subsequent expeditions,  I was seeing creatures at hydrothermal vents  and sometimes things that I had never seen before,  sometimes things that no one had seen before,  that actually were not described by science  at the time that we saw them and imaged them.': '當我們做了一些後來的旅程時,我在水熱風中看到生物,有時我以前從未見過的東西,有時以前沒有人見過的東西,實際上在我們看到它們時,科學並沒有描述它們。',
#  'So, I was completely smitten by this,  and had to do more.': '所以,我完全感染了这一点,我不得不做更多。',
#  'And so, I actually made a kind of curious decision.': '因此,我实际上做了一种好奇的决定。',
#  'After the success of "Titanic,"  I said, "OK, I\'m going to park my day job  as a Hollywood movie maker,  and I\'m going to go be a full-time explorer for a while."': '在“泰坦尼克”的成功之后,我说:“好吧,我会停下我的日常工作作为好莱坞电影制作人,我会去做一个全日制探险家一段时间。',
#  'And so, we started planning these  expeditions.': '因此,我们开始计划这些行程。',
#  'And we wound up going to the Bismark,  and exploring it with robotic vehicles.': '然后,我们去拜斯马克,用机器人车来探索它。',
#  'We went back to the Titanic wreck.': '我们又回到了泰坦尼克号。',
#  'We took little bots that we had created  that spooled a fiber optic.': '我们采取了我们创造的小机器人,这些机器人喷发了纤维光学。',
#  'And the idea was to go in and do an interior  survey of that ship, which had never been done.': '而想法是进去并对那艘船进行内部调查,这从未完成过。',
#  "Nobody had ever looked inside the wreck. They didn't have the means to do it,  so we created technology to do it.": '他们没有办法做到这一点,所以我们创造了技术做到这一点。',
#  'So, you know, here I am now, on the deck  of Titanic, sitting in a submersible,  and looking out at planks that look much like this,  where I knew that the band had played.': '所以,你知道,我现在在泰坦尼克号的地板上,坐在一个潜水的地板上,看着看起来很像这个,在那里我知道乐队已经演奏了。',
#  "And I'm flying a little robotic vehicle  through the corridor of the ship.": '我正在飞行一辆小机器人车,穿过船的走廊。',
#  'When I say, "I\'m operating it,"  but my mind is in the vehicle.': '当我说“我正在运行它”,但我的头脑在车内。',
#  'I felt like I was physically present  inside the shipwreck of Titanic.': '我觉得自己在泰坦尼克号的船内身体存在。',
#  "And it was the most surreal kind  of deja vu experience I've ever had,  because I would know before I turned a corner  what was going to be there before the lights  of the vehicle actually revealed it,  because I had walked the set for months  when we were making the movie. And the set was based as an exact replica  on the blueprints of the ship.": '而且,这是我曾经有过的最令人惊叹的 deja vu 体验,因为我会知道,在我转过一个角落之前,车辆的灯光实际上揭示了它,因为我在拍摄电影时走了几个月的集合,而集合是基于船上的蓝印的准确复制。',
#  'So, it was this absolutely remarkable experience.': '因此,这是这个绝对令人惊叹的体验。',
#  'And it really made me realize that  the telepresence experience --  that you actually can have these robotic avatars,  then your consciousness is injected into the vehicle,  into this other form of existence.': '而且,它真的让我意识到,望远的体验 - 你实际上可以拥有这些机器人 avatars,然后你的意识被注入车辆,在这个另一种形式的存在。',
#  'It was really, really quite profound.': '这是真的,真的很深。',
#  'And it may be a little bit of a glimpse as to what might be happening  some decades out  as we start to have cyborg bodies  for exploration or for other means  in many sort of  post-human futures  that I can imagine,  So, having done these expeditions,  and really beginning to appreciate what was down there,  such as at the deep ocean vents  where we had these amazing, amazing animals --': '而且可能有一点关于可能在几十年后发生的事情,当我们开始在许多后人类未来中进行探索或其他手段的网络尸体时,我可以想象,所以,完成了这些探险,并真正开始欣赏下面的东西,例如在深海的风中,我们有这些令人惊叹的,令人惊叹的动物。',
#  "they're basically aliens right here on Earth.": '他们基本上是外星人在地球上。',
#  'They live in an environment of chemosynthesis.': '他们生活在化合物的环境中。',
#  "They don't survive on sunlight-based  system the way we do.": '它们不会像我们所做的那样在基于太阳光的系统上生存。',
#  "And so, you're seeing animals that are living next to  water plumes.": '因此,你看到活在水池旁边的动物。',
#  "You think they can't possibly exist.": '你认为它们可能无法存在。',
#  "At the same time  I was getting very interested in space science as well --  again, it's the science fiction influence, as a kid.": '同时,我对太空科学也非常感兴趣 - 又一次,这是科幻的影响力,作为一个孩子。',
#  'And I wound up getting involved with  the space community,  really involved with NASA,  sitting on the NASA advisory board,  planning actual space missions,  going to Russia, going through the pre-cosmonaut  biomedical protocols,  and all these sorts of things,  to actually go and fly to the international space station  with our 3D camera systems.': '我受伤了与太空社区的参与,真的与NASA的参与,坐在NASA的咨询委员会,计划实际的太空任务,去俄罗斯,通过前宇航的生物医学协议,以及所有这些东西,实际上去飞到国际太空站与我们的3D摄像机系统。',
#  'And this was fascinating.': '这也是令人兴奋的。',
#  'But what I wound up doing was bringing space scientists  with us into the deep.': '但我所做的事情是把太空科学家带到深处。',
#  'And taking them down so that they had access --  astrobiologists, planetary scientists,  people who were interested in these extreme environments --  taking them down to the vents, and letting them see,  and take samples and test instruments, and so on.': '把它们拿下来,以便他们有访问 - 天文学家,行星科学家,那些对这些极端环境感兴趣的人 - 把它们拿到风中,让它们看到,采取样品和测试工具等。',
#  'So, here we were making documentary films,  but actually doing science,  and actually doing space science.': '所以,在这里,我们正在制作纪录片,但实际上做科学,实际上做太空科学。',
#  "I'd completely closed the loop  between being the science fiction fan,  and doing this stuff for real.": '我完全关闭了成为科学幻想的粉丝之间的圈子,并将这一点变成现实。',
#  'And you know, along the way in this journey  of discovery,  I learned a lot.': '你知道,在这个发现之旅的路上,我学到了很多东西。',
#  'I learned a lot about science. But I also learned a lot  about leadership.': '我学到了很多关于科学的,但我也学到了很多关于领导的。',
#  'Now you think director has got to be a leader,  leader of, captain of the ship, and all that sort of thing.': '现在你认为导演必须是领袖,领袖,船长,以及所有这些东西。',
#  "I didn't really learn about leadership until I did these expeditions.": '我没有真正了解领导力,直到我完成了这些行程。',
#  'Because I had to, at a certain point, say,  "What am I doing out here?': '因为在某个时候,我不得不说:“我在这里做什么?',
#  'Why am I doing this? What do I get out of it?"': '為什麼我這樣做?我從中得出什麼?」',
#  "We don't make money at these damn shows.": '我们不会在这些丑陋的表演中赚钱。',
#  'We barely break even. There is no fame in it.': '我们几乎没有打破,没有名声。',
#  'People sort of think I went away between "Titanic" and "Avatar" and was buffing my nails  someplace, sitting at the beach.': '人们认为我走在“泰坦尼克号”和“阿瓦塔”之间,并在海滩上坐着,在某个地方擦我的指甲。',
#  'Made all these films, made all these documentary films  for a very limited audience.': '制作了所有这些电影,制作了所有这些纪录片,为一个非常有限的观众。',
#  'No fame, no glory, no money. What are you doing?': '没有名声,没有荣耀,没有钱,你在做什么?',
#  "You're doing it for the task itself,  for the challenge --  and the ocean is the most challenging environment there is --  for the thrill of discovery, and for that strange bond that happens  when a small group of people form a tightly knit team.": '你正在为这个任务本身,为这个挑战 - 海洋是最具挑战性的环境 - 为发现的兴奋,以及当一个小群人形成一个紧紧的团队时发生的那个奇怪的联系。',
#  'Because we would do these things with 10, 12 people,  working for years at a time,  sometimes at sea for two, three months at a time.': '因为我们会用10、12人做这些事情,同时工作多年,有时在海上工作两、三个月。',
#  "And in that bond, you realize  that the most important thing  is the respect that you have for them  and that they have for you, that you've done a task  that you can't explain to someone else.": '在这段关系中,你意识到,最重要的事情是你对他们有尊重,他们对你有尊重,你完成了一个你不能向别人解释的任务。',
#  'When you come back to the shore and you say,  "We had to do this, and the fiber optic, and the attentuation,  and the this and the that,  all the technology of it, and the difficulty,  the human-performance aspects of working at sea,"  you can\'t explain it to people. It\'s that thing that  maybe cops have, or people in combat that have gone through something together  and they know they can never explain it.': '当你回到海岸,你说:“我们必须这样做,纤维光学,注意力,这一点,这一点,这一点,这一点,这一点,这一点,这一点,这一点,这一点,这一点,这一点,这一点,这一点,这一点,这一点,这一点,这一点,这一点,这一点,这一点,这一点,这一点,这一点。',
#  'Creates a bond, creates a bond of respect.': '它创造了一个联盟,创造了一个尊重的联盟。',
#  'So, when I came back to make my next movie,  which was "Avatar,"  I tried to apply that same principle of leadership,  which is that you respect your team,  and you earn their respect in return.': '所以,当我回来制作我的下一部电影,那是“Avatar”,我试图应用同样的领导原则,即你尊重你的团队,你赢得他们的尊重相反。',
#  'And it really changed the dynamic.': '它真的改变了动态。',
#  'So, here I was again with a small team,  in uncharted territory,  doing "Avatar," coming up with new technology  that didn\'t exist before.': '因此,在这里,我再次与一个小团队,在未分配的领土上,做“Avatar”,带着新的技术,以前没有存在。',
#  'Tremendously exciting.': '非常令人兴奋。',
#  'Tremendously challenging.': '非常有挑战。',
#  'And we became a family, over a four-and-half year period.': '我們成為一個家庭,在四年半的期間。',
#  'And it completely changed how I do movies.': '这完全改变了我拍电影的方式。',
#  'So, people have commented on how, "Well, you know,  you brought back the ocean organisms  and put them on the planet of Pandora."': '因此,人们对如何发表评论,“好吧,你知道,你把海洋生物带回来,把它们放在潘多拉的星球上。',
#  'To me, it was more of a fundamental way of doing business,  the process itself, that changed as a result of that.': '对于我来说,这是一个基本的方式做生意,这个过程本身,因而改变了。',
#  'So, what can we synthesize out of all this?': '那么,我们能从这一切中总结什么呢?',
#  'You know, what are the lessons learned?': '你知道什么是学到的教训?',
#  'Well, I think number one is  curiosity.': '我认为第一个是好奇心。',
#  "It's the most powerful thing you own.": '这是你拥有的最强大的东西。',
#  'Imagination is a force  that can actually manifest a reality.': '想象力是一种能真正表现出现实的力量。',
#  'And the respect of your team  is more important than all the  laurels in the world.': '你的团队的尊重比世界上所有的劳埃尔更重要。',
#  'I have young filmmakers  come up to me and say, "Give me some advice for doing this."': '我有年轻的电影制作人来到我身边,说:“给我一些建议来做这件事。',
#  'And I say, "Don\'t put limitations on yourself.': '我说:“不要把限制放在自己身上。',
#  'Other people will do that for you -- don\'t do it to yourself,  don\'t bet against yourself,  and take risks."': '其他人会为你做 - 不要为自己做,不要对自己赌,并冒险。',
#  'NASA has this phrase that they like:  "Failure is not an option."': 'NASA有这个句子,他们喜欢:“失败不是一个选择。',
#  "But failure has to be an option  in art and in exploration, because it's a leap of faith.": '但失败必须是艺术和探索的选择,因为它是信仰的跳跃。',
#  'And no important endeavor  that required innovation  was done without risk.': '没有任何重要的努力,需要的创新是没有风险的。',
#  'You have to be willing to take those risks.': '你必须愿意承担这些风险。',
#  "So, that's the thought I would leave you with,  is that in whatever you're doing,  failure is an option,  but fear is not. Thank you.": '所以,这就是我会留下你的想法,就是在你所做的一切中,失败是一种选择,但恐惧不是。',
#  "If I can leave you with one big idea today,  it's that the whole of the data  in which we consume  is greater that the sum of the parts,  and instead of thinking about information overload,  what I'd like you to think about is how  we can use information so that patterns pop  and we can see trends that would otherwise be invisible.": '如果我今天可以留给你一个伟大的想法,那就是我们所消耗的所有数据比零件的总额更大,而不是思考信息过量,我希望你思考的是我们如何使用信息,以便模型流行,我们可以看到趋势,否则会是看不见的。',
#  "So what we're looking at right here is a typical mortality chart  organized by age.": '因此,我们在这里正确地看的是根据年龄组织的典型死亡率图。',
#  "This tool that I'm using here is a little experiment.": '我在这里使用的这个工具是一个小实验。',
#  "It's called Pivot, and with Pivot what I can do  is I can choose to filter in one particular cause of deaths -- say, accidents.": '它被称为Pivot,而与Pivot我可以做的是我可以选择在一个特定的死亡原因过滤 - 说,事故。',
#  "And, right away, I see there's a different pattern that emerges.": '而且,我立刻看到一个不同的模式出现了。',
#  "This is because, in the mid-area here,  people are at their most active,  and over here they're at their most frail.": '这是因为,在这里的中间地区,人们处于最活跃的位置,而且在这里,他们处于最脆弱的位置。',
#  'We can step back out again  and then reorganize the data by cause of death,  seeing that circulatory diseases and cancer  are the usual suspects, but not for everyone.': '我们可以再次退出,然后根据死亡原因重新组织数据,看到循环疾病和癌症是常见的嫌疑人,但不是所有人。',
#  'If we go ahead and we filter by age --  say 40 years or less --  we see that accidents are actually  the greatest cause that people have to be worried about.': '如果我们前进并根据年龄过滤 - 说40岁或更少 - 我们看到事故实际上是人们需要担心的最大原因。',
#  "And if you drill into that, it's especially the case for men.": '如果你在做这件事,这尤其适用于男人。',
#  'So you get the idea  that viewing information, viewing data in this way,  is a lot like swimming  in a living information info-graphic.': '因此,你得到了观看信息的想法,以这种方式观看数据,就像在生活信息信息图中游泳一样。',
#  'And if we can do this for raw data,  why not do it for content as well?': '如果我们能为原始数据做到这一点,为什么不为内容做到这一点呢?',
#  "So what we have right here  is the cover of every single Sports Illustrated  It's all here; it's all on the web.": '因此,我們在這裡正確的是每個單一的Sports Illustrated的覆蓋,它都在這裡;它都在網上。',
#  'You can go back to your rooms and try this after my talk.': '你可以回到你的房间,在我的谈话后尝试这个。',
#  'With Pivot, you can drill into a decade.': '有了Pivot,你可以在十年内挖掘。',
#  'You can drill into a particular year.': '你可以在一个特定的年份。',
#  'You can jump right into a specific issue.': '你可以直接跳到一个特定的问题。',
#  "So I'm looking at this; I see the athletes  that have appeared in this issue, the sports.": '所以我正在看这件事;我看到在这个问题上出现的运动员,体育运动员。',
#  "I'm a Lance Armstrong fan, so I'll go ahead and I'll click on that,  which reveals, for me, all the issues  in which Lance Armstrong's been a part of.": '我是一个Lance Armstrong的粉丝,所以我会继续前进,我会点击它,这对我来说揭示了Lance Armstrong的一部分。',
#  'Now, if I want to just kind of take a peek at these,  I might think,  "Well, what about taking a look at all of cycling?"': '现在,如果我只是想在这些,我可能会想,“好吧,怎么看所有的骑自行车?”',
#  'So I can step back, and expand on that.': '所以我可以回头,并扩展到这一点。',
#  'And I see Greg LeMond now.': '现在我看到了格雷格·莱蒙德。',
#  "And so you get the idea that when you  navigate over information this way --  going narrower, broader,  backing in, backing out --  you're not searching, you're not browsing.": '因此,你得到了想法,当你以这种方式浏览信息 - 变得更紧,更宽,支持,支持 - 你不是搜索,你不是浏览。',
#  "You're doing something that's actually a little bit different.": '你正在做一些实际上有点不同的事情。',
#  "It's in between, and we think it changes  the way information can be used.": '它在中间,我们认为它改变了信息可以使用的方式。',
#  "So I want to extrapolate on this idea a bit  with something that's a little bit crazy.": '所以我想在这个想法上稍微抽出一些有点疯狂的东西。',
#  "What we're done here is we've taken every single Wikipedia page  and we reduced it down to a little summary.": '我们在这里所做的是,我们已经采取了每个维基百科页面,并将其缩小到一个小总结。',
#  'So the summary consists of just a little synopsis  and an icon to indicate the topical area that it comes from.': '因此,概述仅仅由一个小概述和一个图标,以表明它来自的主题区域。',
#  "I'm only showing the top 500  most popular Wikipedia pages right here.": '我只是在这里展示顶级500个最受欢迎的维基百科页面。',
#  'But even in this limited view,  we can do a lot of things.': '但即使在这个有限的观点,我们也可以做很多事情。',
#  'Right away, we get a sense of what are the topical domains  that are most popular on Wikipedia.': '即时,我们就知道什么是维基百科上最受欢迎的主题域。',
#  ...}

# %% [markdown]
# ## Combine (For ref only)

# %%
df = pd.DataFrame({
    'en_test': en_texts,
    'zh_test': zh_texts
})

df
# Out:
#                                                 en_test  \
# 0     Several years ago here at TED, Peter Skillman ...
# 1     And the idea's pretty simple:  Teams of four h...
# 2                     The marshmallow has to be on top.
# 3     And, though it seems really simple, it's actua...
# 4     And so, I thought this was an interesting idea...
# ...                                                 ...
# 8544  And the answer is, the ability to seek goals  ...
# 8545  from a long-term drive  to increase future fre...
# 8546  Finally, Richard Feynman, famous physicist,  o...
# 8547  My equivalent of that statement  to pass on to...
# 8548                               Thank you very much.
#
#                                                 zh_test
# 0       几年前，在TED大会上， Peter Skillman 介绍了一个设计挑战 叫做“棉花糖挑战”
# 1     是个非常简单的主意 要求一组四人的团队搭建一个独立的最高建筑 材料是20根意大利面条 一段胶...
# 2                                            棉花糖必须放在最上面
# 3                          这虽然看似简单，其实并不容易 因为它要求人们 迅速地合作
# 4                            我觉得这是个有趣的主意 我把它放到了设计专题讨论会上
# ...                                                 ...
# 8544  答案是，寻找目标的能力 将直接遵循它， 道理是这样的： 就像你要穿过一条隧道， 你未来道路空...
# 8545                                长期的驱动， 为了增加未来的行动自由。
# 8546  最后，理查德 · 费曼， 这位著名的物理学家， 曾经写道， 如果人类文明被摧毁 并且你只能将...
# 8547  我与这句话等同的声明， 来传递给后代， 帮助他们建立人工智能 或是帮助他们理解 人类的智慧，...
# 8548                                              非常感谢。
#
# [8549 rows x 2 columns]

# %% [markdown]
# ## Match correct translation

# %%
def find_translated(text):
    return hash_map[text]
df['M2M100'] = df['en_test'].apply(find_translated) # since conversion was in batches and not in order
df.to_csv('translated_benchmarks.csv', index=False)

# %% [markdown]
# ## Run from here if translated_benchmarks.csv is already present

# %%
import pandas as pd
from sacrebleu.metrics import BLEU, CHRF, TER
from rouge_chinese import Rouge
import jieba # you can use any other word cutting library
import torch
from bert_score import score
current = pd.read_csv('translated_benchmarks.csv')
current
# Out:
#                                                 en_test  \
# 0     Several years ago here at TED, Peter Skillman ...
# 1     And the idea's pretty simple:  Teams of four h...
# 2                     The marshmallow has to be on top.
# 3     And, though it seems really simple, it's actua...
# 4     And so, I thought this was an interesting idea...
# ...                                                 ...
# 8544  And the answer is, the ability to seek goals  ...
# 8545  from a long-term drive  to increase future fre...
# 8546  Finally, Richard Feynman, famous physicist,  o...
# 8547  My equivalent of that statement  to pass on to...
# 8548                               Thank you very much.
#
#                                                 zh_test  \
# 0       几年前，在TED大会上， Peter Skillman 介绍了一个设计挑战 叫做“棉花糖挑战”
# 1     是个非常简单的主意 要求一组四人的团队搭建一个独立的最高建筑 材料是20根意大利面条 一段胶...
# 2                                            棉花糖必须放在最上面
# 3                          这虽然看似简单，其实并不容易 因为它要求人们 迅速地合作
# 4                            我觉得这是个有趣的主意 我把它放到了设计专题讨论会上
# ...                                                 ...
# 8544  答案是，寻找目标的能力 将直接遵循它， 道理是这样的： 就像你要穿过一条隧道， 你未来道路空...
# 8545                                长期的驱动， 为了增加未来的行动自由。
# 8546  最后，理查德 · 费曼， 这位著名的物理学家， 曾经写道， 如果人类文明被摧毁 并且你只能将...
# 8547  我与这句话等同的声明， 来传递给后代， 帮助他们建立人工智能 或是帮助他们理解 人类的智慧，...
# 8548                                              非常感谢。
#
#                                                  M2M100
# 0                 几年前,在这里在TED,彼得·斯基尔曼介绍了一个设计挑战称为马斯马洛挑战。
# 1      这个想法很简单:四个团队必须从20块蜘蛛、一块绳子、一块绳子和一块火柴中建造最高的自由站式结构。
# 2                                             马歇尔必须在顶部。
# 3                  虽然它看起来很简单,但它实际上是相当困难的,因为它迫使人们非常快地合作。
# 4                        因此,我认为这是一个有趣的想法,我把它纳入了一个设计研讨会。
# ...                                                 ...
# 8544  答案是,追求目标的能力将直接从这个意义上跟随:就像你在未来的路线空间中穿过隧道,一个瓶子,以...
# 8545                                 从长期的努力,以提高未来的行动自由。
# 8546  最后,著名的物理学家理查德·费恩曼(Richard Feynman)曾经写过,如果人类文明被...
# 8547  我的同等于把这个声明传递给后代,帮助他们建立人工智能或帮助他们理解人类智能,是如下:智能应该...
# 8548                                             非常感谢你。
#
# [8549 rows x 3 columns]

# %% [markdown]
# # Calc Scores

# %%
def calc_bleu_scores(row): 
    r , c = row['zh_test'].rstrip(), row['M2M100'].rstrip()
    sacre_ref = [[r]] # list of list of text
    sacre_c = [c] # list of text
    scores = {}
    for i in range(1, 5):
        bleu = BLEU(smooth_method='exp', tokenize='zh', max_ngram_order=i)
        s = bleu.corpus_score(sacre_c, sacre_ref).score  
        scores[f'BLEU-{i}'] = "{:.3f}".format(s)
    # chrf 
    chrf = CHRF(word_order=0, beta=0, eps_smoothing=False)
    s = chrf.corpus_score(sacre_c, sacre_ref).score
    scores['CHRF'] = "{:.3f}".format(s)
    # chrf++ 
    chrf = CHRF(word_order=2, beta=0, eps_smoothing=False)
    s = chrf.corpus_score(sacre_c, sacre_ref).score
    scores['CHRF++'] = "{:.3f}".format(s)
    # ter 
    ter = TER(asian_support=True, normalized=True)
    s = ter.corpus_score(sacre_c, sacre_ref).score
    scores['TER'] = "{:.3f}".format(s)
    # rouge w jieba
    rouge_ref = ' '.join(jieba.cut(r))
    rouge_c = ' '.join(jieba.cut(c))
    rouge = Rouge()
    s = rouge.get_scores(rouge_c, rouge_ref)
    for m in s[0]:
        for m2 in s[0][m]:
            scores[f'{m}-{m2}'] = "{:.3f}".format(s[0][m][m2])
    # bert score 
    P, R, F = score(sacre_c, sacre_ref, lang='zh')
    P, R, F = P.item(), R.item(), F.item()
    scores['BERTSCORE-R']= "{:.3f}".format(R)
    scores['BERTSCORE-P']= "{:.3f}".format(P)
    scores['BERTSCORE-F']= "{:.3f}".format(F)

    return pd.Series(scores)


current[['BLEU-1', 'BLEU-2', 'BLEU-3', 'BLEU-4', 'CHRF', 'CHRF++', 'TER', 'ROUGE1-R','ROUGE1-P','ROUGE1-F','ROUGE2-R','ROUGE2-P','ROUGE2-F','ROUGEL-R','ROUGEL-P','ROUGEL-F','BERTSCORE-R','BERTSCORE-P','BERTSCORE-F']] = current.apply(calc_bleu_scores, axis=1)
current.to_csv('Benchmark_M2M100_Evaluations.csv',index=False)

# %%
current
# Out:
#                                                 en_test  \
# 0     Several years ago here at TED, Peter Skillman ...
# 1     And the idea's pretty simple:  Teams of four h...
# 2                     The marshmallow has to be on top.
# 3     And, though it seems really simple, it's actua...
# 4     And so, I thought this was an interesting idea...
# ...                                                 ...
# 8544  And the answer is, the ability to seek goals  ...
# 8545  from a long-term drive  to increase future fre...
# 8546  Finally, Richard Feynman, famous physicist,  o...
# 8547  My equivalent of that statement  to pass on to...
# 8548                               Thank you very much.
#
#                                                 zh_test  \
# 0       几年前，在TED大会上， Peter Skillman 介绍了一个设计挑战 叫做“棉花糖挑战”
# 1     是个非常简单的主意 要求一组四人的团队搭建一个独立的最高建筑 材料是20根意大利面条 一段胶...
# 2                                            棉花糖必须放在最上面
# 3                          这虽然看似简单，其实并不容易 因为它要求人们 迅速地合作
# 4                            我觉得这是个有趣的主意 我把它放到了设计专题讨论会上
# ...                                                 ...
# 8544  答案是，寻找目标的能力 将直接遵循它， 道理是这样的： 就像你要穿过一条隧道， 你未来道路空...
# 8545                                长期的驱动， 为了增加未来的行动自由。
# 8546  最后，理查德 · 费曼， 这位著名的物理学家， 曾经写道， 如果人类文明被摧毁 并且你只能将...
# 8547  我与这句话等同的声明， 来传递给后代， 帮助他们建立人工智能 或是帮助他们理解 人类的智慧，...
# 8548                                              非常感谢。
#
#                                                  M2M100  BLEU-1  BLEU-2  \
# 0                 几年前,在这里在TED,彼得·斯基尔曼介绍了一个设计挑战称为马斯马洛挑战。  45.714  40.168
# 1      这个想法很简单:四个团队必须从20块蜘蛛、一块绳子、一块绳子和一块火柴中建造最高的自由站式结构。  33.708  17.958
# 2                                             马歇尔必须在顶部。  29.828  18.266
# 3                  虽然它看起来很简单,但它实际上是相当困难的,因为它迫使人们非常快地合作。  38.889  27.889
# 4                        因此,我认为这是一个有趣的想法,我把它纳入了一个设计研讨会。  50.000  34.740
# ...                                                 ...     ...     ...
# 8544  答案是,追求目标的能力将直接从这个意义上跟随:就像你在未来的路线空间中穿过隧道,一个瓶子,以...  64.105  51.488
# 8545                                 从长期的努力,以提高未来的行动自由。  61.111  56.880
# 8546  最后,著名的物理学家理查德·费恩曼(Richard Feynman)曾经写过,如果人类文明被...  67.126  55.713
# 8547  我的同等于把这个声明传递给后代,帮助他们建立人工智能或帮助他们理解人类智能,是如下:智能应该...  72.592  61.161
# 8548                                             非常感谢你。  83.333  70.711
#
#       BLEU-3  BLEU-4    CHRF  CHRF++     TER  ... ROUGE1-F ROUGE2-R ROUGE2-P  \
# 0     33.945  29.264  27.391  23.478  63.333  ...    0.462    0.300    0.273
# 1      6.807   3.544   8.725   7.478  84.906  ...    0.235    0.000    0.000
# 2     12.872   9.443   7.639   6.548  70.000  ...    0.182    0.000    0.000
# 3     16.601   9.125  10.795   9.253  88.462  ...    0.343    0.067    0.048
# 4     23.472  14.793  14.759  12.651  68.000  ...    0.452    0.200    0.176
# ...      ...     ...     ...     ...     ...  ...      ...      ...      ...
# 8544  40.693  32.915  30.541  26.178  47.321  ...    0.596    0.254    0.270
# 8545  52.115  46.606  40.464  34.683  44.444  ...    0.571    0.500    0.455
# 8546  46.144  38.640  30.832  23.124  36.885  ...    0.606    0.274    0.294
# 8547  52.568  45.813  41.802  35.830  38.043  ...    0.644    0.333    0.367
# 8548  62.996  53.728  45.333  37.778  20.000  ...    0.800    0.000    0.000
#
#      ROUGE2-F ROUGEL-R ROUGEL-P ROUGEL-F BERTSCORE-R BERTSCORE-P BERTSCORE-F
# 0       0.286    0.476    0.435    0.455       0.831       0.770       0.800
# 1       0.000    0.133    0.138    0.136       0.700       0.718       0.709
# 2       0.000    0.167    0.200    0.182       0.718       0.721       0.719
# 3       0.056    0.375    0.273    0.316       0.810       0.768       0.788
# 4       0.187    0.500    0.421    0.457       0.863       0.822       0.842
# ...       ...      ...      ...      ...         ...         ...         ...
# 8544    0.262    0.486    0.507    0.496       0.833       0.844       0.838
# 8545    0.476    0.636    0.583    0.609       0.863       0.855       0.859
# 8546    0.284    0.514    0.535    0.524       0.882       0.892       0.887
# 8547    0.350    0.571    0.627    0.598       0.878       0.897       0.887
# 8548    0.000    1.000    0.667    0.800       0.960       0.900       0.929
#
# [8549 rows x 22 columns]
